# %% [markdown]
# # Alexandria"Bride of the Mediterranean"

# %% [markdown]
# ## Introduction

# %% [markdown]
# When tourists visiting Egypt going to Landmarks and museums in Cairo like Pyramids and others in Luxor and Aswan only, but what about Alexandria? What's in Alexandria? The third-largest city in Egypt after Cairo and Giza, seventh-largest city in Africa, and a major economic centre. With a total population of 5,200,000, Alexandria is the largest city on the Mediterranean – also called the "Bride of the Mediterranean" the fourth-largest city in the Arab world and the ninth-largest urban area in Africa.

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# 1.Table of Contents

# %% [markdown]
# 2.Business Problem

# %% [markdown]
# 3.Data Collection

# %% [markdown]
# 4.Import necessary Libraries

# %% [markdown]
# 5.Using Foursquare API

# %% [markdown]
# 6.Converting Alex data to pandas dataframe

# %% [markdown]
# 7.Visualizing Alex Data

# %% [markdown]
# ## 1. Business Problem

# %% [markdown]
# Most of the tourists didn't know what's in Alexandria? So, In this project I will search for 20 place in Alex. This will help the trippers who have enthusiasm and passion in travelling to go to Alex and explore those places, and helps the tourists who want visit Alex without needing to spend a long time exploring the town and search about famous landmarks.On the other hand, It will help hotels, Small shops, shrines, temples and Tourist resorts also, It will make Alex people happening for receiving tourists.

# %% [markdown]
# ## 2. Data Collection

# %% [markdown]
# It's useful a quick glance to see how the overall aim of the project. The data is obviously the central factor in the project. Mainly the data source in this project is that which provides the location data for entertainment and archaeological places in Alex. The data is sourced from foursquare (https://foursquare.com) This provides an incredible wealth of data. Which provides a lot of information about places in Alex such as id, name, categories, lat(latitude), lng(longitude) and others from which we can extract the coordinates and nicely present the maps of the cities, ​So that it can be cleanly and comprehensively visualized.

# %% [markdown]
# ## 3. Import necessary Libraries

# %%
import pandas as pd  # library for data analsysis
import numpy as np  # library to handle data in a vectorized manner
import requests # library to handle requests

# !pip install geopy
from geopy.geocoders import Nominatim  # module to convert an address into latitude and longitude values

from pandas.io.json import json_normalize # tranforming json file into a pandas dataframe library

! pip install folium==0.5.0
import folium # plotting library

print("Done")
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: geopy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geopy) (1.50)
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 6.9 MB/s  eta 0:00:01
# Collecting branca
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.11.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium==0.5.0) (3.0.4)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76240 sha256=7ba14fef39233b452fdb69d1fa962d23200eebf4bbf2bd6b8ade84924017bbf0
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/b2/2f/2c/109e446b990d663ea5ce9b078b5e7c1a9c45cca91f377080f8
# Successfully built folium
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.5.0
# Done

# %% [markdown]
# ## 4. Using Foursquare API

# %% [markdown]
# #### -Getting an access token

# %%
CLIENT_ID = '5LBEGGHUU0GBOMBJY3M4JHKTDLONTD5O3HJ5W3WJXJC43KBL' # My Foursquare ID
CLIENT_SECRET = 'KKVZ2E5MMCUV0RD4O3QX11WG3XV5B1BRGBH5JOINFNCCAXWJ' # My Foursquare Secret
ACCESS_TOKEN = 'LIRLZ4ESH0ZRZ2MDUSBLTXX0FZNLUYPFXMRE44NM4ZHX0KL0' # My FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
search_query = 'Fun'
print('My credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# My credentails:
# CLIENT_ID: 5LBEGGHUU0GBOMBJY3M4JHKTDLONTD5O3HJ5W3WJXJC43KBL
# CLIENT_SECRET:KKVZ2E5MMCUV0RD4O3QX11WG3XV5B1BRGBH5JOINFNCCAXWJ

# %% [markdown]
# #### In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent (to_explorer), as shown below.¶

# %%
address = "Alexandria, IN,Egypt"
geolocator= Nominatim( user_agent = "to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Egypt are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Egypt are 30.9693218, 29.82774415.

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&query={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION,search_query, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=5LBEGGHUU0GBOMBJY3M4JHKTDLONTD5O3HJ5W3WJXJC43KBL&client_secret=KKVZ2E5MMCUV0RD4O3QX11WG3XV5B1BRGBH5JOINFNCCAXWJ&ll=30.9693218,29.82774415&v=20180604&query=Fun&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '60c62ff046a2120b92d597e1'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 30000,
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'query': 'fun',
#   'totalResults': 23,
#   'suggestedBounds': {'ne': {'lat': 31.235463723822246,
#     'lng': 29.99141454833948},
#    'sw': {'lat': 30.740062424360662, 'lng': 29.716598079252716}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509674cfe4b0147d2e77fa92',
#        'name': 'Borg El Arab Stadium (ستاد برج العرب)',
#        'location': {'address': 'Cairo - Borg El-Arab Desert Rd',
#         'lat': 30.999664705672668,
#         'lng': 29.729089736938477,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.999664705672668,
#           'lng': 29.729089736938477}],
#         'distance': 10002,
#         'cc': 'EG',
#         'city': 'العامرية',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Cairo - Borg El-Arab Desert Rd',
#          'العامرية',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d188941735',
#          'name': 'Soccer Stadium',
#          'pluralName': 'Soccer Stadiums',
#          'shortName': 'Soccer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509674cfe4b0147d2e77fa92-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a8201313149b97ae24be483',
#        'name': 'VOX Cinemas',
#        'location': {'address': 'Alexandria City Center',
#         'crossStreet': 'Suez Canal Rd',
#         'lat': 31.16606310751623,
#         'lng': 29.93298866137508,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.16606310751623,
#           'lng': 29.93298866137508}],
#         'distance': 24090,
#         'cc': 'EG',
#         'city': 'Moharam Bek',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Alexandria City Center (Suez Canal Rd)',
#          'Moharam Bek',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a8201313149b97ae24be483-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dcd8b71d164679b8ce935c3',
#        'name': 'Alexandria Opera House',
#        'location': {'address': 'Sayed Darwish Theatre,',
#         'lat': 31.19675264670403,
#         'lng': 29.90200721772115,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.19675264670403,
#           'lng': 29.90200721772115}],
#         'distance': 26288,
#         'cc': 'EG',
#         'city': 'الإسكندرية',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Sayed Darwish Theatre,',
#          'الإسكندرية',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d136941735',
#          'name': 'Opera House',
#          'pluralName': 'Opera Houses',
#          'shortName': 'Opera House',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_operahouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dcd8b71d164679b8ce935c3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca04cfb031337043ab179d5',
#        'name': 'Catacombs of Kom El Shoqafa (مقابر كوم الشقافة)',
#        'location': {'address': 'Al-Nasseriya St.',
#         'lat': 31.17898608062476,
#         'lng': 29.89309337233515,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.17898608062476,
#           'lng': 29.89309337233515}],
#         'distance': 24156,
#         'cc': 'EG',
#         'city': 'الإسكندرية',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Al-Nasseriya St.',
#          'الإسكندرية',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca04cfb031337043ab179d5-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5284f1e011d29748e9b64b31',
#        'name': 'Rio Cinema Rooftop',
#        'location': {'address': 'Cinema Rio - 37 Fouad St',
#         'lat': 31.19656848021114,
#         'lng': 29.903498620912924,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.19656848021114,
#           'lng': 29.903498620912924}],
#         'distance': 26307,
#         'cc': 'EG',
#         'city': 'الإسكندرية',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Cinema Rio - 37 Fouad St',
#          'الإسكندرية',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5284f1e011d29748e9b64b31-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd5cd885631c9b6edbaa430',
#        'name': 'Bibliotheca Alexandrina (مكتبة الإسكندرية)',
#        'location': {'address': 'Emtedad Dr. Abd Al Hamid Sayed- Al Azaritah',
#         'lat': 31.20856707665388,
#         'lng': 29.90886224371427,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.20856707665388,
#           'lng': 29.90886224371427}],
#         'distance': 27732,
#         'postalCode': '21526',
#         'cc': 'EG',
#         'city': 'Shatby',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Emtedad Dr. Abd Al Hamid Sayed- Al Azaritah',
#          'Shatby',
#          'اسكندرية',
#          '21526',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d12f941735',
#          'name': 'Library',
#          'pluralName': 'Libraries',
#          'shortName': 'Library',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/library_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd5cd885631c9b6edbaa430-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9d84c97865a0930d11e97a',
#        'name': "Institut Français d'Égypte",
#        'location': {'address': '30 Nabi Daniel St',
#         'lat': 31.195301483214635,
#         'lng': 29.901439763678336,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.195301483214635,
#           'lng': 29.901439763678336}],
#         'distance': 26118,
#         'cc': 'EG',
#         'city': 'Al ‘Aţţārīn',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['30 Nabi Daniel St',
#          'العطارين',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a32',
#          'name': 'Cultural Center',
#          'pluralName': 'Cultural Centers',
#          'shortName': 'Cultural Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9d84c97865a0930d11e97a-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9ed5d79bf0a35d09e7020b',
#        'name': 'Roman Amphitheater (المسرح الرومانى)',
#        'location': {'address': 'Safeya Zaghloul St.',
#         'lat': 31.194184900959854,
#         'lng': 29.90374603178937,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.194184900959854,
#           'lng': 29.90374603178937}],
#         'distance': 26059,
#         'cc': 'EG',
#         'city': 'الإسكندرية',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Safeya Zaghloul St.',
#          'الإسكندرية',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9ed5d79bf0a35d09e7020b-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fda3552e4b0251901377565',
#        'name': 'Teatro Eskendria (تياترو اسكندرية)',
#        'location': {'address': '25 Fouad St.',
#         'lat': 31.196125930098077,
#         'lng': 29.903045250444602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.196125930098077,
#           'lng': 29.903045250444602}],
#         'distance': 26248,
#         'cc': 'EG',
#         'city': 'Downtown',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['25 Fouad St.', 'Downtown', 'اسكندرية', 'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fda3552e4b0251901377565-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca062acd3c2b60cb673dcbc',
#        'name': 'Citadel of Qaitbay (قلعة قايتباى)',
#        'location': {'address': 'As Sayalah Sharq',
#         'lat': 31.212945482937627,
#         'lng': 29.884037201555333,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.212945482937627,
#           'lng': 29.884037201555333}],
#         'distance': 27645,
#         'cc': 'EG',
#         'city': 'Al Gomrok',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['As Sayalah Sharq',
#          'Al Gomrok',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca062acd3c2b60cb673dcbc-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d1f25bee56f6ea82a3e6b1d',
#        'name': 'Alexandria National Museum (متحف الاسكندرية القومي)',
#        'location': {'address': '131 El-Shaheed Galal El-Desouky St',
#         'lat': 31.20088752312989,
#         'lng': 29.913010832786963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.20088752312989,
#           'lng': 29.913010832786963}],
#         'distance': 27028,
#         'cc': 'EG',
#         'city': 'Qism Bāb Sharqī',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['131 El-Shaheed Galal El-Desouky St',
#          'Qism Bāb Sharqī',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d1f25bee56f6ea82a3e6b1d-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509cd134e4b035e93d9456c8',
#        'name': "Pompey's Pillar (عمود السوارى)",
#        'location': {'address': 'Amud Al Sawary',
#         'lat': 31.181745029626157,
#         'lng': 29.897056213459624,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.181745029626157,
#           'lng': 29.897056213459624}],
#         'distance': 24552,
#         'cc': 'EG',
#         'city': 'Karmouz',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Amud Al Sawary', 'Karmouz', 'اسكندرية', 'مصر']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509cd134e4b035e93d9456c8-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eaafb2b2c5b5d71e706a83b',
#        'name': 'Shallalat Gardens (حديقة الشلالات)',
#        'location': {'lat': 31.20207281783358,
#         'lng': 29.91364345053989,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.20207281783358,
#           'lng': 29.91364345053989}],
#         'distance': 27172,
#         'cc': 'EG',
#         'city': 'Al Shatby',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Al Shatby', 'اسكندرية', 'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eaafb2b2c5b5d71e706a83b-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c49350f3013a59326b36de2',
#        'name': 'Africa Safari Park',
#        'location': {'address': 'Cairo Alexandria desert road',
#         'crossStreet': '164 km from Cairo, 68 from Alex',
#         'lat': 30.76258066524528,
#         'lng': 29.978922890653717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.76258066524528,
#           'lng': 29.978922890653717}],
#         'distance': 27172,
#         'cc': 'EG',
#         'city': 'At Taftīsh ath Thānī',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Cairo Alexandria desert road (164 km from Cairo, 68 from Alex)',
#          'At Taftīsh ath Thānī',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d182941735',
#          'name': 'Theme Park',
#          'pluralName': 'Theme Parks',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c49350f3013a59326b36de2-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1fc8d2b4e62d7fe72be093',
#        'name': 'Cineplex Green Plaza Cinema',
#        'location': {'address': 'Green Plaza',
#         'crossStreet': '15 May Rd',
#         'lat': 31.205215314104898,
#         'lng': 29.965439531089377,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.205215314104898,
#           'lng': 29.965439531089377}],
#         'distance': 29357,
#         'cc': 'EG',
#         'city': 'الإسكندرية',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Green Plaza (15 May Rd)',
#          'الإسكندرية',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1fc8d2b4e62d7fe72be093-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f61ae0ce4b06b1a17d4d742',
#        'name': 'Lion Village (قرية الاسد)',
#        'location': {'address': 'Alexandria Cairo Desert Road',
#         'crossStreet': 'Km 59',
#         'lat': 30.818387787146875,
#         'lng': 29.92546563939711,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 30.818387787146875,
#           'lng': 29.92546563939711}],
#         'distance': 19220,
#         'cc': 'EG',
#         'city': 'Al Noubareya',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Alexandria Cairo Desert Road (Km 59)',
#          'Al Noubareya',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d182941735',
#          'name': 'Theme Park',
#          'pluralName': 'Theme Parks',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f61ae0ce4b06b1a17d4d742-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c815b63647db7135af402bb',
#        'name': 'Karamantas',
#        'location': {'address': '14 May Rd',
#         'crossStreet': 'Green Plaza',
#         'lat': 31.205379136107883,
#         'lng': 29.96603324269545,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.205379136107883,
#           'lng': 29.96603324269545}],
#         'distance': 29399,
#         'cc': 'EG',
#         'city': 'سموحة',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['14 May Rd (Green Plaza)',
#          'سموحة',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d1e1931735',
#          'name': 'Arcade',
#          'pluralName': 'Arcades',
#          'shortName': 'Arcade',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/arcade_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c815b63647db7135af402bb-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0bbe6ad823b1f7623ceb5c',
#        'name': 'Renaissance Royal Cinema',
#        'location': {'address': 'Fouad St - Raml Station',
#         'crossStreet': 'Beside Sayed Darwish Theatre',
#         'lat': 31.196393667393096,
#         'lng': 29.902639389038082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.196393667393096,
#           'lng': 29.902639389038082}],
#         'distance': 26266,
#         'cc': 'EG',
#         'city': 'الإسكندرية',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Fouad St - Raml Station (Beside Sayed Darwish Theatre)',
#          'الإسكندرية',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d0bbe6ad823b1f7623ceb5c-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfeac4862a38cfa95e95932',
#        'name': 'Cinema Amir (سينما أمير)',
#        'location': {'address': '41 El Hurria Road',
#         'crossStreet': 'El Raml',
#         'lat': 31.19707735773475,
#         'lng': 29.904119569678233,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.19707735773475,
#           'lng': 29.904119569678233}],
#         'distance': 26378,
#         'cc': 'EG',
#         'city': 'El Raml',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['41 El Hurria Road (El Raml)',
#          'El Raml',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfeac4862a38cfa95e95932-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52e525ce498e19014c98ce87',
#        'name': 'Sculpture of Alexander The Great (تمثال الاسكندر الاكبر)',
#        'location': {'address': 'Abd El Moneim Riad Sq',
#         'lat': 31.200627216722033,
#         'lng': 29.915874534469733,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.200627216722033,
#           'lng': 29.915874534469733}],
#         'distance': 27084,
#         'cc': 'EG',
#         'city': 'Ash Shāţibī',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Abd El Moneim Riad Sq',
#          'الشاطبي',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '52e81612bcbc57f1066b79ed',
#          'name': 'Outdoor Sculpture',
#          'pluralName': 'Outdoor Sculptures',
#          'shortName': 'Outdoor Sculpture',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52e525ce498e19014c98ce87-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5028e20fe4b07a366d0c6fd8',
#        'name': 'Alexandria Aquarium Museum (متحف الأحياء المائية)',
#        'location': {'address': 'Qaitbay St',
#         'lat': 31.21253535915782,
#         'lng': 29.884389638900753,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.21253535915782,
#           'lng': 29.884389638900753}],
#         'distance': 27607,
#         'cc': 'EG',
#         'city': 'Al Anfūshī',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Qaitbay St', 'Al Anfūshī', 'اسكندرية', 'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d191941735',
#          'name': 'Science Museum',
#          'pluralName': 'Science Museums',
#          'shortName': 'Science Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_science_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5028e20fe4b07a366d0c6fd8-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fcd07bee4b0131cb4a3b7de',
#        'name': 'Bayram El Tunsi Theater (مسرح بيرم التونسي)',
#        'location': {'address': 'El Geish Rd',
#         'lat': 31.211334407676688,
#         'lng': 29.91598185151471,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.211334407676688,
#           'lng': 29.91598185151471}],
#         'distance': 28223,
#         'cc': 'EG',
#         'city': 'Ash Shāţibī',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['El Geish Rd', 'الشاطبي', 'اسكندرية', 'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d137941735',
#          'name': 'Theater',
#          'pluralName': 'Theaters',
#          'shortName': 'Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fcd07bee4b0131cb4a3b7de-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5110c927e4b0cb0bdaa57a98',
#        'name': 'Alexandria Zoo (حديقة الحيوان بالإسكندرية)',
#        'location': {'address': 'Albert Al Awal St',
#         'crossStreet': 'Ezbet Saad',
#         'lat': 31.20561224368596,
#         'lng': 29.944564725458285,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 31.20561224368596,
#           'lng': 29.944564725458285}],
#         'distance': 28564,
#         'cc': 'EG',
#         'city': 'سموحة',
#         'state': 'اسكندرية',
#         'country': 'مصر',
#         'formattedAddress': ['Albert Al Awal St (Ezbet Saad)',
#          'سموحة',
#          'اسكندرية',
#          'مصر']},
#        'categories': [{'id': '4bf58dd8d48988d17b941735',
#          'name': 'Zoo',
#          'pluralName': 'Zoos',
#          'shortName': 'Zoo',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/zoo_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5110c927e4b0cb0bdaa57a98-22'}]}]}}

# %% [markdown]
# #### From the Foursquare lab in the previous module, we know that all the information is in the items key. Before we proceed, let's borrow the get_category_type function from the Foursquare lab.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# # 5. Converting Alex data to pandas dataframe

# %% [markdown]
# #### Now we are ready to clean the json and structure it into a pandas dataframe

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

nearby_venues
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
#                          referralId  reasons.count  \
# 0    e-0-509674cfe4b0147d2e77fa92-0              0
# 1    e-0-5a8201313149b97ae24be483-1              0
# 2    e-0-4dcd8b71d164679b8ce935c3-2              0
# 3    e-0-4ca04cfb031337043ab179d5-3              0
# 4    e-0-5284f1e011d29748e9b64b31-4              0
# 5    e-0-4bd5cd885631c9b6edbaa430-5              0
# 6    e-0-4d9d84c97865a0930d11e97a-6              0
# 7    e-0-4d9ed5d79bf0a35d09e7020b-7              0
# 8    e-0-4fda3552e4b0251901377565-8              0
# 9    e-0-4ca062acd3c2b60cb673dcbc-9              0
# 10  e-0-4d1f25bee56f6ea82a3e6b1d-10              0
# 11  e-0-509cd134e4b035e93d9456c8-11              0
# 12  e-0-4eaafb2b2c5b5d71e706a83b-12              0
# 13  e-0-4c49350f3013a59326b36de2-13              0
# 14  e-0-4c1fc8d2b4e62d7fe72be093-14              0
# 15  e-0-4f61ae0ce4b06b1a17d4d742-15              0
# 16  e-0-4c815b63647db7135af402bb-16              0
# 17  e-0-4d0bbe6ad823b1f7623ceb5c-17              0
# 18  e-0-4cfeac4862a38cfa95e95932-18              0
# 19  e-0-52e525ce498e19014c98ce87-19              0
# 20  e-0-5028e20fe4b07a366d0c6fd8-20              0
# 21  e-0-4fcd07bee4b0131cb4a3b7de-21              0
# 22  e-0-5110c927e4b0cb0bdaa57a98-22              0
#
#                                         reasons.items  \
# 0   [{'summary': 'This spot is popular', 'type': '...
# 1   [{'summary': 'This spot is popular', 'type': '...
# 2   [{'summary': 'This spot is popular', 'type': '...
# 3   [{'summary': 'This spot is popular', 'type': '...
# 4   [{'summary': 'This spot is popular', 'type': '...
# 5   [{'summary': 'This spot is popular', 'type': '...
# 6   [{'summary': 'This spot is popular', 'type': '...
# 7   [{'summary': 'This spot is popular', 'type': '...
# 8   [{'summary': 'This spot is popular', 'type': '...
# 9   [{'summary': 'This spot is popular', 'type': '...
# 10  [{'summary': 'This spot is popular', 'type': '...
# 11  [{'summary': 'This spot is popular', 'type': '...
# 12  [{'summary': 'This spot is popular', 'type': '...
# 13  [{'summary': 'This spot is popular', 'type': '...
# 14  [{'summary': 'This spot is popular', 'type': '...
# 15  [{'summary': 'This spot is popular', 'type': '...
# 16  [{'summary': 'This spot is popular', 'type': '...
# 17  [{'summary': 'This spot is popular', 'type': '...
# 18  [{'summary': 'This spot is popular', 'type': '...
# 19  [{'summary': 'This spot is popular', 'type': '...
# 20  [{'summary': 'This spot is popular', 'type': '...
# 21  [{'summary': 'This spot is popular', 'type': '...
# 22  [{'summary': 'This spot is popular', 'type': '...
#
#                     venue.id  \
# 0   509674cfe4b0147d2e77fa92
# 1   5a8201313149b97ae24be483
# 2   4dcd8b71d164679b8ce935c3
# 3   4ca04cfb031337043ab179d5
# 4   5284f1e011d29748e9b64b31
# 5   4bd5cd885631c9b6edbaa430
# 6   4d9d84c97865a0930d11e97a
# 7   4d9ed5d79bf0a35d09e7020b
# 8   4fda3552e4b0251901377565
# 9   4ca062acd3c2b60cb673dcbc
# 10  4d1f25bee56f6ea82a3e6b1d
# 11  509cd134e4b035e93d9456c8
# 12  4eaafb2b2c5b5d71e706a83b
# 13  4c49350f3013a59326b36de2
# 14  4c1fc8d2b4e62d7fe72be093
# 15  4f61ae0ce4b06b1a17d4d742
# 16  4c815b63647db7135af402bb
# 17  4d0bbe6ad823b1f7623ceb5c
# 18  4cfeac4862a38cfa95e95932
# 19  52e525ce498e19014c98ce87
# 20  5028e20fe4b07a366d0c6fd8
# 21  4fcd07bee4b0131cb4a3b7de
# 22  5110c927e4b0cb0bdaa57a98
#
#                                            venue.name  \
# 0               Borg El Arab Stadium (ستاد برج العرب)
# 1                                         VOX Cinemas
# 2                              Alexandria Opera House
# 3     Catacombs of Kom El Shoqafa (مقابر كوم الشقافة)
# 4                                  Rio Cinema Rooftop
# 5          Bibliotheca Alexandrina (مكتبة الإسكندرية)
# 6                          Institut Français d'Égypte
# 7                Roman Amphitheater (المسرح الرومانى)
# 8                  Teatro Eskendria (تياترو اسكندرية)
# 9                   Citadel of Qaitbay (قلعة قايتباى)
# 10  Alexandria National Museum (متحف الاسكندرية ال...
# 11                     Pompey's Pillar (عمود السوارى)
# 12                 Shallalat Gardens (حديقة الشلالات)
# 13                                 Africa Safari Park
# 14                        Cineplex Green Plaza Cinema
# 15                          Lion Village (قرية الاسد)
# 16                                         Karamantas
# 17                           Renaissance Royal Cinema
# 18                           Cinema Amir (سينما أمير)
# 19  Sculpture of Alexander The Great (تمثال الاسكن...
# 20  Alexandria Aquarium Museum (متحف الأحياء المائية)
# 21        Bayram El Tunsi Theater (مسرح بيرم التونسي)
# 22         Alexandria Zoo (حديقة الحيوان بالإسكندرية)
#
#                          venue.location.address  venue.location.lat  \
# 0                Cairo - Borg El-Arab Desert Rd           30.999665
# 1                        Alexandria City Center           31.166063
# 2                        Sayed Darwish Theatre,           31.196753
# 3                              Al-Nasseriya St.           31.178986
# 4                      Cinema Rio - 37 Fouad St           31.196568
# 5   Emtedad Dr. Abd Al Hamid Sayed- Al Azaritah           31.208567
# 6                             30 Nabi Daniel St           31.195301
# 7                           Safeya Zaghloul St.           31.194185
# 8                                  25 Fouad St.           31.196126
# 9                              As Sayalah Sharq           31.212945
# 10           131 El-Shaheed Galal El-Desouky St           31.200888
# 11                               Amud Al Sawary           31.181745
# 12                                          NaN           31.202073
# 13                 Cairo Alexandria desert road           30.762581
# 14                                  Green Plaza           31.205215
# 15                 Alexandria Cairo Desert Road           30.818388
# 16                                    14 May Rd           31.205379
# 17                      Fouad St - Raml Station           31.196394
# 18                            41 El Hurria Road           31.197077
# 19                        Abd El Moneim Riad Sq           31.200627
# 20                                   Qaitbay St           31.212535
# 21                                  El Geish Rd           31.211334
# 22                            Albert Al Awal St           31.205612
#
#     venue.location.lng                      venue.location.labeledLatLngs  \
# 0            29.729090  [{'label': 'display', 'lat': 30.99966470567266...
# 1            29.932989  [{'label': 'display', 'lat': 31.16606310751623...
# 2            29.902007  [{'label': 'display', 'lat': 31.19675264670403...
# 3            29.893093  [{'label': 'display', 'lat': 31.17898608062476...
# 4            29.903499  [{'label': 'display', 'lat': 31.19656848021114...
# 5            29.908862  [{'label': 'display', 'lat': 31.20856707665388...
# 6            29.901440  [{'label': 'display', 'lat': 31.19530148321463...
# 7            29.903746  [{'label': 'display', 'lat': 31.19418490095985...
# 8            29.903045  [{'label': 'display', 'lat': 31.19612593009807...
# 9            29.884037  [{'label': 'display', 'lat': 31.21294548293762...
# 10           29.913011  [{'label': 'display', 'lat': 31.20088752312989...
# 11           29.897056  [{'label': 'display', 'lat': 31.18174502962615...
# 12           29.913643  [{'label': 'display', 'lat': 31.20207281783358...
# 13           29.978923  [{'label': 'display', 'lat': 30.76258066524528...
# 14           29.965440  [{'label': 'display', 'lat': 31.20521531410489...
# 15           29.925466  [{'label': 'display', 'lat': 30.81838778714687...
# 16           29.966033  [{'label': 'display', 'lat': 31.20537913610788...
# 17           29.902639  [{'label': 'display', 'lat': 31.19639366739309...
# 18           29.904120  [{'label': 'display', 'lat': 31.19707735773475...
# 19           29.915875  [{'label': 'display', 'lat': 31.20062721672203...
# 20           29.884390  [{'label': 'display', 'lat': 31.21253535915782...
# 21           29.915982  [{'label': 'display', 'lat': 31.21133440767668...
# 22           29.944565  [{'label': 'display', 'lat': 31.20561224368596...
#
#     venue.location.distance venue.location.cc   venue.location.city  \
# 0                     10002                EG              العامرية
# 1                     24090                EG           Moharam Bek
# 2                     26288                EG            الإسكندرية
# 3                     24156                EG            الإسكندرية
# 4                     26307                EG            الإسكندرية
# 5                     27732                EG                Shatby
# 6                     26118                EG           Al ‘Aţţārīn
# 7                     26059                EG            الإسكندرية
# 8                     26248                EG              Downtown
# 9                     27645                EG             Al Gomrok
# 10                    27028                EG       Qism Bāb Sharqī
# 11                    24552                EG               Karmouz
# 12                    27172                EG             Al Shatby
# 13                    27172                EG  At Taftīsh ath Thānī
# 14                    29357                EG            الإسكندرية
# 15                    19220                EG          Al Noubareya
# 16                    29399                EG                 سموحة
# 17                    26266                EG            الإسكندرية
# 18                    26378                EG               El Raml
# 19                    27084                EG           Ash Shāţibī
# 20                    27607                EG            Al Anfūshī
# 21                    28223                EG           Ash Shāţibī
# 22                    28564                EG                 سموحة
#
#    venue.location.state venue.location.country  \
# 0              اسكندرية                    مصر
# 1              اسكندرية                    مصر
# 2              اسكندرية                    مصر
# 3              اسكندرية                    مصر
# 4              اسكندرية                    مصر
# 5              اسكندرية                    مصر
# 6              اسكندرية                    مصر
# 7              اسكندرية                    مصر
# 8              اسكندرية                    مصر
# 9              اسكندرية                    مصر
# 10             اسكندرية                    مصر
# 11             اسكندرية                    مصر
# 12             اسكندرية                    مصر
# 13             اسكندرية                    مصر
# 14             اسكندرية                    مصر
# 15             اسكندرية                    مصر
# 16             اسكندرية                    مصر
# 17             اسكندرية                    مصر
# 18             اسكندرية                    مصر
# 19             اسكندرية                    مصر
# 20             اسكندرية                    مصر
# 21             اسكندرية                    مصر
# 22             اسكندرية                    مصر
#
#                       venue.location.formattedAddress  \
# 0   [Cairo - Borg El-Arab Desert Rd, العامرية, اسك...
# 1   [Alexandria City Center (Suez Canal Rd), Mohar...
# 2   [Sayed Darwish Theatre,, الإسكندرية, اسكندرية,...
# 3       [Al-Nasseriya St., الإسكندرية, اسكندرية, مصر]
# 4   [Cinema Rio - 37 Fouad St, الإسكندرية, اسكندري...
# 5   [Emtedad Dr. Abd Al Hamid Sayed- Al Azaritah, ...
# 6        [30 Nabi Daniel St, العطارين, اسكندرية, مصر]
# 7    [Safeya Zaghloul St., الإسكندرية, اسكندرية, مصر]
# 8             [25 Fouad St., Downtown, اسكندرية, مصر]
# 9        [As Sayalah Sharq, Al Gomrok, اسكندرية, مصر]
# 10  [131 El-Shaheed Galal El-Desouky St, Qism Bāb ...
# 11           [Amud Al Sawary, Karmouz, اسكندرية, مصر]
# 12                         [Al Shatby, اسكندرية, مصر]
# 13  [Cairo Alexandria desert road (164 km from Cai...
# 14  [Green Plaza (15 May Rd), الإسكندرية, اسكندرية...
# 15  [Alexandria Cairo Desert Road (Km 59), Al Noub...
# 16    [14 May Rd (Green Plaza), سموحة, اسكندرية, مصر]
# 17  [Fouad St - Raml Station (Beside Sayed Darwish...
# 18  [41 El Hurria Road (El Raml), El Raml, اسكندري...
# 19    [Abd El Moneim Riad Sq, الشاطبي, اسكندرية, مصر]
# 20            [Qaitbay St, Al Anfūshī, اسكندرية, مصر]
# 21              [El Geish Rd, الشاطبي, اسكندرية, مصر]
# 22  [Albert Al Awal St (Ezbet Saad), سموحة, اسكندر...
#
#                                      venue.categories  venue.photos.count  \
# 0   [{'id': '4bf58dd8d48988d188941735', 'name': 'S...                   0
# 1   [{'id': '4bf58dd8d48988d180941735', 'name': 'M...                   0
# 2   [{'id': '4bf58dd8d48988d136941735', 'name': 'O...                   0
# 3   [{'id': '4deefb944765f83613cdba6e', 'name': 'H...                   0
# 4   [{'id': '5032792091d4c4b30a586d5c', 'name': 'C...                   0
# 5   [{'id': '4bf58dd8d48988d12f941735', 'name': 'L...                   0
# 6   [{'id': '52e81612bcbc57f1066b7a32', 'name': 'C...                   0
# 7   [{'id': '4deefb944765f83613cdba6e', 'name': 'H...                   0
# 8   [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...                   0
# 9   [{'id': '4deefb944765f83613cdba6e', 'name': 'H...                   0
# 10  [{'id': '4bf58dd8d48988d181941735', 'name': 'M...                   0
# 11  [{'id': '4deefb944765f83613cdba6e', 'name': 'H...                   0
# 12  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...                   0
# 13  [{'id': '4bf58dd8d48988d182941735', 'name': 'T...                   0
# 14  [{'id': '4bf58dd8d48988d180941735', 'name': 'M...                   0
# 15  [{'id': '4bf58dd8d48988d182941735', 'name': 'T...                   0
# 16  [{'id': '4bf58dd8d48988d1e1931735', 'name': 'A...                   0
# 17  [{'id': '4bf58dd8d48988d180941735', 'name': 'M...                   0
# 18  [{'id': '4bf58dd8d48988d17f941735', 'name': 'M...                   0
# 19  [{'id': '52e81612bcbc57f1066b79ed', 'name': 'O...                   0
# 20  [{'id': '4bf58dd8d48988d191941735', 'name': 'S...                   0
# 21  [{'id': '4bf58dd8d48988d137941735', 'name': 'T...                   0
# 22  [{'id': '4bf58dd8d48988d17b941735', 'name': 'Z...                   0
#
#    venue.photos.groups       venue.location.crossStreet  \
# 0                   []                              NaN
# 1                   []                    Suez Canal Rd
# 2                   []                              NaN
# 3                   []                              NaN
# 4                   []                              NaN
# 5                   []                              NaN
# 6                   []                              NaN
# 7                   []                              NaN
# 8                   []                              NaN
# 9                   []                              NaN
# 10                  []                              NaN
# 11                  []                              NaN
# 12                  []                              NaN
# 13                  []  164 km from Cairo, 68 from Alex
# 14                  []                        15 May Rd
# 15                  []                            Km 59
# 16                  []                      Green Plaza
# 17                  []     Beside Sayed Darwish Theatre
# 18                  []                          El Raml
# 19                  []                              NaN
# 20                  []                              NaN
# 21                  []                              NaN
# 22                  []                       Ezbet Saad
#
#    venue.location.postalCode
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                      21526
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN

# %% [markdown]
# #### From the Foursquare lab in the previous module, we know that all the information is in the items key. Before we proceed, let's borrow the get_category_type function from the Foursquare lab.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# #### Cleaning and filtering columns

# %%
alex = results['response']['groups'][0]['items']
    
df_alex = json_normalize(alex) # flatten JSON

# filter columns
filtered_columns = ['venue.id','venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
df_alex =df_alex.loc[:, filtered_columns]

# filter the category for each row
df_alex['venue.categories'] = df_alex.apply(get_category_type, axis=1)

# clean columns
df_alex.columns = [col.split(".")[-1] for col in df_alex.columns]

df_alex

# %% [markdown]
# # 6. Visualizing Alex Data

# %% [markdown]
# Let's visualize best 20 places in Alexandria

# %%
df_alex.name

# %% [markdown]
# #### using folium (plotting library) to mapping the data

# %%
ALEX_MAP = folium.Map(location=[latitude, longitude],tiles= "Mapbox Bright", zoom_start=10) # generate map centred around Alex
# add a red circle marker to represent ALex
folium.CircleMarker([latitude, longitude],
    radius=10,
    color='red',
    popup='Alex',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(ALEX_MAP)

# add the best 20 places in Alexandria
for lat, lng, label in zip(df_alex.lat, df_alex.lng, df_alex.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(ALEX_MAP)
 # display map
ALEX_MAP

# %% [markdown]
# # Capstone Project -Best 20 places in Alexandria

# %% [markdown]
# # Thanks
